# %%
# !pip install scipy
# !pip install scikit-learn==1.3.0
# Out:
# Requirement already satisfied: scipy in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (from scipy) (1.26.2)
# Requirement already satisfied: scikit-learn==1.3.0 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.26.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.13.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/davidzumaquero/miniconda3/envs/tmf-env/lib/python3.11/site-packages (from scikit-learn==1.3.0) (2.2.0)

# %%
# Importamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Creación de datos
x_values = np.random.uniform(low=-2, high=2, size=400)
y_values = np.random.uniform(low=-2, high=2, size=400)
circle_points_x = []
circle_points_y = []
no_circle_points_x = []
no_circle_points_y = []
for x, y in zip(x_values,y_values):
  if x**2+y**2<0.9:
    circle_points_x.append(x)
    circle_points_y.append(y)
  elif x**2+y**2>1.75 :
    no_circle_points_x.append(x)
    no_circle_points_y.append(y)

class_1 = [circle_points_x]+[circle_points_y]+[[1]*len(circle_points_x)]
class_0 = [no_circle_points_x]+[no_circle_points_y]+[[0]*len(no_circle_points_x)]
data_list = [class_1[0]+class_0[0],class_1[1]+class_0[1],class_1[2]+class_0[2]]
data_t = list(map(list, zip(*data_list)))
df = pd.DataFrame(data_t,columns=['x','y','label'])

# %%
# Visualización de datos
plt.scatter(circle_points_x, circle_points_y, label = 'Clase 0')
plt.scatter(no_circle_points_x, no_circle_points_y, label = 'Clase 1')
plt.axis('equal')
plt.axis([-1.6,1.6,-1.6,1.6]) 
plt.legend(loc = "upper left")
plt.savefig('logistic_regresion_circle_data.jpg')

# %%
# Visualización del límite de decisión
theta = np.linspace(0, 2*np.pi, 100)
r= 1.2
x = r*np.cos(theta)
y = r*np.sin(theta)
plt.scatter(circle_points_x, circle_points_y, label = 'Clase 0')
plt.scatter(no_circle_points_x, no_circle_points_y, label = 'Clase 1')
plt.plot(x,y,label = 'Límite de decisión', color = 'r')
plt.axis('equal')
plt.axis([-1.6,1.6,-1.6,1.6]) 
plt.legend(loc = "upper left")
plt.savefig('logistic_regresion_circle_boundary.jpg')

# %%
# Implementamos el modelo
def logistic_polinomial_regression(degree, x, y):
  poly = PolynomialFeatures(degree, interaction_only=False, include_bias=False)
  X_poly = poly.fit_transform(x)
  lr = LogisticRegression()
  lr.fit(X_poly,y)
  predictions = lr.predict(X_poly)
  class_1_p = x[predictions==1]
  class_0_p = x[predictions==0]
  return class_1_p, class_0_p

class_1_p, class_0_p = logistic_polinomial_regression(2,df[['x','y']], df['label'])
